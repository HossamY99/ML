# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
SEED = ___

# %% [markdown]
# # Deceptive Content Detection for Hotel Reviews
#
# The aim of this lab is to get a handle on basic natural language processing techniques. The application concerns whether a hotel review is truthful or deceptive.
#
# The dataset given has several attributes:
# - deceptive: binary label: truthful or deceptive
# - hotel: what hotel is the review about
# - polarity: whether the opinion is positive or negative
# - source: the platform the comment was written on (like TripAdvisor)
# - text: the review
#
# For the sake of simplicity you can only use the text to predict whether the review is deceitful or truthful.
#
# **1) Data Loading and Exploration:**
# - **load the dataset**
# - **check and handle missing values**
# - **check and handle duplicate texts**
# - **look at the class distribution.**

# %%
#your code here

# %% [markdown]
# **2) Plot the wordcloud for the dataset.**

# %%
import wordcloud

#your code here

# %%
X = ___
y = ___

# %% [markdown]
# **3) Text Cleaning: implement a function to clean the text implementing the following cleaning objectives:**
# - **convert all letters to lowercase**
# - **remove all punctuation and non-alphabetical characters**
# - **remove stopwords**
# - **stem the words**
# - **apply this function to your text dataset.**

# %%
from string import punctuation
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

stop_words = stopwords.words('english')
porter = PorterStemmer()

def clean_text(text):
    #your code here
    return cleaned_text

#apply the function on X

# %% [markdown]
# **4) Naive Bayes:**
# - **use TF-IDF to compute features representing the text**
# - **split the data for training and testing**
# - **train a Naive Bayes classifier**
# - **report on the performance of the model on the test set.**

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB

#your code here

# %% [markdown]
# **5) Recurrent Neural Network:**
# - **use tokenization (integer encoding) to represent the text for the embedding network.**
# - **split the data for training and testing**
# - **train a recurrent neural network (RNN) using word embeddings that are learned during training.**
# - **plot the learning curves**
# - **report the model's performance on the test set.**

# %%
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.backend import clear_session
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, GRU, Dropout, Dense, BatchNormalization

tensorflow.random.set_seed(___)

MAX_NB_WORDS = ___
MAX_SEQUENCE_LENGTH = ___

#tokenize the dataset
___
VOCAB_SIZE = ___

#pad the dataset
___

# %%
EMBEDDING_DIM = ___

#your model here
